# %% [markdown]
# <a href="https://colab.research.google.com/github/hre1oo/ARTI308_Machine-learning/blob/LAB_3/Data_Visualization_Seaborn_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization - Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
sns.barplot(x='day', y='total_bill', data=tips)
plt.show()

# %%
sns.boxplot(x='day', y='tip', data=tips)
plt.show()

# %%
sns.heatmap(tips.select_dtypes(include=['number']).corr(), annot=True)
plt.show()
